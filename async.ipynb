# %%
import time

def ambil_data_a():
    time.sleep(3)  # nunggu 3 detik, program berhenti total
    return "data A"

def ambil_data_b():
    time.sleep(4)
    return "data B"

a = ambil_data_a()  # nunggu 3 detik
b = ambil_data_b()  # nunggu 4 detik lagi
# total: 7 detik

# %%
import asyncio

async def ambil_data_a():
    await asyncio.sleep(2)  # "istirahat", biarkan tugas lain jalan
    return "data A"

async def ambil_data_b():
    await asyncio.sleep(2)
    return "data B"

a, b = await asyncio.gather(ambil_data_a(), ambil_data_b())
# total: ~2 detik, karena keduanya "menunggu" bersamaan
# Out:
# data A
# data B

# %%
def masak_mie():
    print("Mie matang")

masak_mie()   # langsung jalan, langsung selesai
# Out:
# Mie matang

# %%
import asyncio
import time

async def rebus_air():
    print("Mulai rebus air...")
    await asyncio.sleep(4)
    print("Air mendidih!")

async def goreng_telur():
    print("Mulai goreng telur...")
    await asyncio.sleep(2)
    print("Telur matang!")

async def main():
    mulai = time.time()
    await rebus_air()      # tunggu 4 detik dulu, baru lanjut
    await goreng_telur()   # baru mulai setelah rebus air selesai
    print(f"Total waktu: {time.time() - mulai:.1f} detik")

await main()
# Out:
# Mulai rebus air...
# Air mendidih!
# Mulai goreng telur...
# Telur matang!
# Total waktu: 6.0 detik

# %%
async def main():
    mulai = time.time()
    await asyncio.gather(
        rebus_air(),
        goreng_telur(),
    )
    print(f"Total waktu: {time.time() - mulai:.1f} detik")

await main()
# Out:
# Mulai rebus air...
# Mulai goreng telur...
# Telur matang!
# Air mendidih!
# Total waktu: 4.0 detik

# %%
import asyncio

async def run_1():
    print(f"run 1 dimulai")
    await asyncio.sleep(5)
    print(f"============= run 1 selesai =============")
    print(f"run 1 selesai")

async def run_2():
    print(f"run 2 dimulai")
    await asyncio.sleep(3)
    print(f"============= run 2 selesai =============")
    print(f"run 2 selesai")

async def main():
    await asyncio.gather(
        run_1(),
        run_2(),
    )

await main()
# Out:
# run 1 dimulai
# run 2 dimulai
# ============= run 2 selesai =============
# run 2 selesai
# ============= run 1 selesai =============
# run 1 selesai

# %%
it = iter([10, 20, 30])
while True:
    try:
        x = next(it)
    except StopIteration:
        break
    print(x)
# Out:
# 10
# 20
# 30

# %%
def fungsi_saya():
    # 'pesan' adalah variabel lokal
    pesan = "Halo dari dalam fungsi!"
    print(pesan)

# Memanggil fungsi
fungsi_saya() 
# Output: Halo dari dalam fungsi!

# Jika kita mencoba memanggil 'pesan' di luar fungsi, akan terjadi error
# print(pesan)  -> Menghasilkan: NameError: name 'pesan' is not defined
# Out:
# Halo dari dalam fungsi!

# %%
# 'nama' adalah variabel global
nama = "Budi"

def sapa():
    # Fungsi ini bisa membaca variabel global 'nama'
    print(f"Halo, {nama}!")

sapa() 
# Output: Halo, Budi!

print(f"Nama dari luar fungsi: {nama}")
# Output: Nama dari luar fungsi: Budi
# Out:
# Halo, Budi!
# Nama dari luar fungsi: Budi

# %%
response = [{'type': 'text', 'text': "Here is your complete, practical, and well-organized 3-day travel itinerary for your trip from Indonesia to Bangkok, Thailand, scheduled for **September 6–8, 2026**.\n\n---\n\n### **1. Trip Summary**\n* **Destination:** Bangkok, Thailand\n* **Departure From:** Jakarta (Soekarno-Hatta International Airport - CGK), Indonesia\n* **Arrival At:** Bangkok (Suvarnabhumi International Airport - BKK)\n* **Duration:** 3 Days / 2 Nights\n* **Dates:** September 6 – September 8, 2026\n* **Trip Focus:** A short, high-impact cultural and culinary escape focusing on Bangkok’s iconic temples, river views, world-famous street food, and vibrant night markets.\n\n---\n\n### **2. Flight Information**\n* **Outbound Option (Sept 6, 2026):** **Garuda Indonesia (GA866)** or **Bangkok Airways (PG4300)**\n  * **Departure:** CGK (Terminal 3) at 09:30 AM\n  * **Arrival:** BKK at 1:10 PM\n  * *Why:* This morning flight gets you into Bangkok by early afternoon, allowing you to maximize your first day without losing time.\n* **Return Option (Sept 8, 2026):** Book an evening flight back to Jakarta (e.g., between 4:00 PM and 6:00 PM) to make the most of your final day.\n* **Alternative Outbound Flights:** If you prefer other carriers flying the same route and schedule at 12:35 PM arrival, options include **Thai Airways (TG434)**, **Turkish Airlines (TK8028)**, **Lufthansa (LH9713)**, and **Gulf Air (GF6354)** departing CGK at 12:35 PM and arriving at BKK at 4:05 PM.\n* **Note on Pricing:** Please note that live flight APIs and schedules may not provide real-time ticket prices. We recommend checking directly with your preferred airline or travel aggregator (such as Skyscanner or Expedia) to lock in fares and book your tickets.\n\n---\n\n### **3. Hotel Suggestions**\n* **Recommended Pick:** **Somwang Boutique Hotel** \n  * **Estimated Price:** From €40 / night\n  * **Why Stay Here:** It is centrally located, offering great accessibility to Bangkok's cultural core, historical landmarks, and public transit systems (BTS Skytrain / MRT).\n* **Alternative Option:** *Samantan Hotel at Nimman* (approx. €32/night) is another great boutique choice depending on your exact neighborhood preference.\n\n---\n\n### **4. Day-by-Day Itinerary**\n\n#### **Day 1: Arrival, River Vibes, and Chinatown Street Food**\n* **1:10 PM** – Arrive at Suvarnabhumi Airport (BKK). Clear immigration, pick up a local tourist eSIM/SIM card, and take the Airport Rail Link into the city.\n* **3:00 PM** – Check in at the Somwang Boutique Hotel, freshen up, and relax briefly after your flight.\n* **4:30 PM** – Head down to the Chao Phraya River. Take an affordable cross-river ferry to visit **Wat Arun (Temple of Dawn)** as the sun sets over the spires.\n* **7:00 PM** – Travel to **Yaowarat Road (Bangkok Chinatown)** for dinner. Dive into the neon-lit night scene and sample local street food favorites like crispy pork with rice, Chinese rolled noodle soup, and Thai-style desserts.\n* **9:30 PM** – Head back to the hotel to rest up for a busy day ahead.\n\n#### **Day 2: Iconic Temples, Modern Malls, and Night Markets**\n* **8:30 AM** – Start early to beat the crowds at the **Grand Palace and Wat Phra Kaew (Temple of the Emerald Buddha)**. *(Dress code reminder: shoulders and knees must be covered).*\n* **11:00 AM** – Walk over to **Wat Pho (Temple of the Reclining Buddha)** to view the massive 46-meter long golden reclining Buddha.\n* **12:30 PM** – Enjoy a casual lunch at a riverside cafe (try a classic Pad Thai or Tom Yum Goong).\n* **2:30 PM** – Take the MRT or a ride-hailing app (Grab/Bolt) to the Siam area. Explore Bangkok's modern side at **Siam Paragon** or **MBK Center** for shopping and air-conditioned relief.\n* **6:30 PM** – Head to **Jodd Fairs Night Market** (via MRT Rama IX). It is one of the city's trendiest night markets, perfect for trying spicy giant river prawns, volcano spare ribs, and browsing local fashion items.\n* **9:00 PM** – Return to your hotel.\n\n#### **Day 3: Cafes, Last-Minute Souvenirs, and Departure**\n* **9:00 AM** – Enjoy a leisurely breakfast, check out of the hotel, and leave your luggage at the front desk.\n* **10:00 AM** – Visit the peaceful **Erawan Shrine** or explore the trendy cafes around the Ratchathewi or Siam districts.\n* **12:00 PM** – Grab a final authentic Thai lunch (such as Green Curry or Mango Sticky Rice).\n* **1:30 PM** – Pick up your bags from the hotel and head back to BKK Airport via the Airport Rail Link or taxi.\n* **3:30 PM** – Arrive at BKK Airport, clear security, do any last-minute duty-free shopping, and board your evening flight back to Jakarta (CGK).\n\n---\n\n### **5. Estimated Budget**\n* **Flights:** Varies based on booking time (Check live airline rates).\n* **Accommodation:** ~€40 – €80 total for 2 nights.\n* **Food & Drinks:** 800 – 1,500 THB (~IDR 370,000 – 700,000) per day for casual dining and street food.\n* **Transportation & Sightseeing:** 500 – 800 THB (~IDR 230,000 – 370,000) total for BTS/MRT tickets, ferries, and temple entrance fees.\n\n---\n\n### **6. Final Recommendations**\n1. **Currency Exchange:** Bring Indonesian Rupiah (IDR) to exchange to Thai Baht (THB) upon arrival at SuperRich exchange booths (typically found in the airport basement or major city spots) for the best rates. Credit cards are widely accepted in malls, but cash is essential for street food and night markets.\n2. **Getting Around:** Download the **Grab** or **Bolt** apps for easy ride-hailing, but rely primarily on the BTS Skytrain and MRT to effortlessly bypass Bangkok's rush-hour traffic.\n3. **Power Plugs:** Thailand generally uses Type A, B, and C plugs, which are largely compatible with Indonesian electronics, though keeping a universal travel adapter handy is always recommended.", 'extras': {'signature': 'El4KXAERTTIPkO96lZT6hLvPAF5ep7erkLslmPPaSgHvMc3b8MzKrxNnaZCCUfEsopEni1E9tpJvWVCajRqJBHgaSoxg3ljkQ1+fw4fcoa1u6XiF5RBiTf82mAOIP1KI'}}]

# %%
print(response[0]['text'])
# Out:
# Here is your complete, practical, and well-organized 3-day travel itinerary for your trip from Indonesia to Bangkok, Thailand, scheduled for **September 6–8, 2026**.
#
# ---
#
# ### **1. Trip Summary**
# * **Destination:** Bangkok, Thailand
# * **Departure From:** Jakarta (Soekarno-Hatta International Airport - CGK), Indonesia
# * **Arrival At:** Bangkok (Suvarnabhumi International Airport - BKK)
# * **Duration:** 3 Days / 2 Nights
# * **Dates:** September 6 – September 8, 2026
# * **Trip Focus:** A short, high-impact cultural and culinary escape focusing on Bangkok’s iconic temples, river views, world-famous street food, and vibrant night markets.
#
# ---
#
# ### **2. Flight Information**
# * **Outbound Option (Sept 6, 2026):** **Garuda Indonesia (GA866)** or **Bangkok Airways (PG4300)**
#   * **Departure:** CGK (Terminal 3) at 09:30 AM
#   * **Arrival:** BKK at 1:10 PM
# ...

# %%
text =  [{'type': 'text', 'text': '[{"airport_name": "Anaa", "iata_code": "AAA", "icao_code": "NTGA", "city_iata_code": "AAA", "country_name": "French Polynesia", "country_iso2": "PF", "timezone": "Pacific/Tahiti", "gmt": "-10"}, {"airport_name": "Arrabury", "iata_code": "AAB", "icao_code": "YARY", "city_iata_code": "AAB", "country_name": "Australia", "country_iso2": "AU", "timezone": "Australia/Brisbane", "gmt": "10"}, {"airport_name": "El Arish International Airport", "iata_code": "AAC", "icao_code": "HEAR", "city_iata_code": "AAC", "country_name": "Egypt", "country_iso2": "EG", "timezone": "Africa/Cairo", "gmt": "2"}, {"airport_name": "Les Salines", "iata_code": "AAE", "icao_code": "DABB", "city_iata_code": "AAE", "country_name": null, "country_iso2": "DZ", "timezone": "Africa/Algiers", "gmt": "1"}, {"airport_name": "Apalachicola Regional", "iata_code": "AAF", "icao_code": "KAAF", "city_iata_code": "AAF", "country_name": "United States", "country_iso2": "US", "timezone": "America/New_York", "gmt": "-5"}, {"airport_name": "Arapoti", "iata_code": "AAG", "icao_code": "SSYA", "city_iata_code": "AAG", "country_name": "Brazil", "country_iso2": "BR", "timezone": "America/Sao_Paulo", "gmt": "-3"}, {"airport_name": "Aachen/Merzbruck", "iata_code": "AAH", "icao_code": "EDKA", "city_iata_code": "AAH", "country_name": "Germany", "country_iso2": "DE", "timezone": "Europe/Berlin", "gmt": "1"}, {"airport_name": "Arraias", "iata_code": "AAI", "icao_code": "SWRA", "city_iata_code": "AAI", "country_name": "Brazil", "country_iso2": "BR", "timezone": "America/Araguaina", "gmt": "-3"}, {"airport_name": "Aranuka", "iata_code": "AAK", "icao_code": "NGUK", "city_iata_code": "AAK", "country_name": "Kiribati", "country_iso2": "KI", "timezone": "Pacific/Tarawa", "gmt": "12"}, {"airport_name": "Aalborg", "iata_code": "AAL", "icao_code": "EKYT", "city_iata_code": "AAL", "country_name": "Denmark", "country_iso2": "DK", "timezone": "Europe/Copenhagen", "gmt": "1"}]', 'id': 'lc_5b78a33e-c5fc-437e-a342-2cbda3f5653f'}]

# %%
for i, a in enumerate(text,1):
    name = a.get("airport_name", "Unknown")
    iata = a.get("iata_code", "-")
    icao = a.get("icao_code", "-")
    city = a.get("city_iata_code", "-")
    country = a.get("country_name") or "Unknown"
    timezone = a.get("timezone", "-")
    gmt = a.get("gmt", "-")

    print(f"{i}. Airport Name: {name}, IATA: {iata}, ICAO: {icao}, City IATA: {city}, Country: {country}, Timezone: {timezone}, GMT Offset: {gmt}")
# Out:
# 1. Airport Name: Unknown, IATA: -, ICAO: -, City IATA: -, Country: Unknown, Timezone: -, GMT Offset: -

# %%
import json

data = json.loads('''[{"airport_name": "Anaa", "iata_code": "AAA", "icao_code": "NTGA", "city_iata_code": "AAA", "country_name": "French Polynesia", "country_iso2": "PF", "timezone": "Pacific/Tahiti", "gmt": "-10"}, {"airport_name": "Arrabury", "iata_code": "AAB", "icao_code": "YARY", "city_iata_code": "AAB", "country_name": "Australia", "country_iso2": "AU", "timezone": "Australia/Brisbane", "gmt": "10"}, {"airport_name": "El Arish International Airport", "iata_code": "AAC", "icao_code": "HEAR", "city_iata_code": "AAC", "country_name": "Egypt", "country_iso2": "EG", "timezone": "Africa/Cairo", "gmt": "2"}, {"airport_name": "Les Salines", "iata_code": "AAE", "icao_code": "DABB", "city_iata_code": "AAE", "country_name": null, "country_iso2": "DZ", "timezone": "Africa/Algiers", "gmt": "1"}, {"airport_name": "Apalachicola Regional", "iata_code": "AAF", "icao_code": "KAAF", "city_iata_code": "AAF", "country_name": "United States", "country_iso2": "US", "timezone": "America/New_York", "gmt": "-5"}, {"airport_name": "Arapoti", "iata_code": "AAG", "icao_code": "SSYA", "city_iata_code": "AAG", "country_name": "Brazil", "country_iso2": "BR", "timezone": "America/Sao_Paulo", "gmt": "-3"}, {"airport_name": "Aachen/Merzbruck", "iata_code": "AAH", "icao_code": "EDKA", "city_iata_code": "AAH", "country_name": "Germany", "country_iso2": "DE", "timezone": "Europe/Berlin", "gmt": "1"}, {"airport_name": "Arraias", "iata_code": "AAI", "icao_code": "SWRA", "city_iata_code": "AAI", "country_name": "Brazil", "country_iso2": "BR", "timezone": "America/Araguaina", "gmt": "-3"}, {"airport_name": "Aranuka", "iata_code": "AAK", "icao_code": "NGUK", "city_iata_code": "AAK", "country_name": "Kiribati", "country_iso2": "KI", "timezone": "Pacific/Tarawa", "gmt": "12"}, {"airport_name": "Aalborg", "iata_code": "AAL", "icao_code": "EKYT", "city_iata_code": "AAL", "country_name": "Denmark", "country_iso2": "DK", "timezone": "Europe/Copenhagen", "gmt": "1"}]''')

lines = []
for d in data:
    country = d['country_name'] or "Tidak diketahui"
    line = (
        f"Bandara {d['airport_name']} (IATA: {d['iata_code']}, ICAO: {d['icao_code']}) "
        f"terletak di {country} ({d['country_iso2']}), "
        f"zona waktu {d['timezone']} (GMT{d['gmt']})."
    )
    lines.append(line)

prompt_text = "\n".join(lines)
print(prompt_text)
# Out:
# Bandara Anaa (IATA: AAA, ICAO: NTGA) terletak di French Polynesia (PF), zona waktu Pacific/Tahiti (GMT-10).
# Bandara Arrabury (IATA: AAB, ICAO: YARY) terletak di Australia (AU), zona waktu Australia/Brisbane (GMT10).
# Bandara El Arish International Airport (IATA: AAC, ICAO: HEAR) terletak di Egypt (EG), zona waktu Africa/Cairo (GMT2).
# Bandara Les Salines (IATA: AAE, ICAO: DABB) terletak di Tidak diketahui (DZ), zona waktu Africa/Algiers (GMT1).
# Bandara Apalachicola Regional (IATA: AAF, ICAO: KAAF) terletak di United States (US), zona waktu America/New_York (GMT-5).
# Bandara Arapoti (IATA: AAG, ICAO: SSYA) terletak di Brazil (BR), zona waktu America/Sao_Paulo (GMT-3).
# Bandara Aachen/Merzbruck (IATA: AAH, ICAO: EDKA) terletak di Germany (DE), zona waktu Europe/Berlin (GMT1).
# Bandara Arraias (IATA: AAI, ICAO: SWRA) terletak di Brazil (BR), zona waktu America/Araguaina (GMT-3).
# ...

# %%
response = [{'type': 'text', 'text': '{\n  "city": "Jakarta",\n  "forecast": [\n    {\n      "datetime": "2026-09-08 12:00:00",\n      "temperature": 30.46,\n      "weather": "few clouds"\n    },\n    {\n      "datetime": "2026-09-08 15:00:00",\n      "temperature": 29.71,\n      "weather": "broken clouds"\n    },\n    {\n      "datetime": "2026-09-08 18:00:00",\n      "temperature": 28.19,\n      "weather": "broken clouds"\n    },\n    {\n      "datetime": "2026-09-08 21:00:00",\n      "temperature": 26.96,\n      "weather": "broken clouds"\n    },\n    {\n      "datetime": "2026-09-09 00:00:00",\n      "temperature": 27.8,\n      "weather": "scattered clouds"\n    }\n  ]\n}', 'id': 'lc_cfeea8de-fa28-403e-a117-e96900f7be01'}]

# %%
import json

results = []
for item in response:
    content = item.get('text', '')
    if content:
        try:
            data = json.loads(content)
            city = data.get('city', 'Unknown City')
            forecast_list = data.get('forecast', [])
            parts = [f"Weather Forecast for {city}:"]
            for forecast in forecast_list:
                dt = forecast.get('datetime', 'Unknown Time')
                temp = forecast.get('temperature', 'N/A')
                weather = forecast.get('weather', 'N/A')
                parts.append(f"- {dt}: {temp}°C, {weather}")
            results.append("\n".join(parts))
        except json.JSONDecodeError:
            results.append(f"Invalid JSON content: {content}")
    else:
        results.append("No content available.")
print("\n".join(results))
# Out:
# Weather Forecast for Jakarta:
# - 2026-09-08 12:00:00: 30.46°C, few clouds
# - 2026-09-08 15:00:00: 29.71°C, broken clouds
# - 2026-09-08 18:00:00: 28.19°C, broken clouds
# - 2026-09-08 21:00:00: 26.96°C, broken clouds
# - 2026-09-09 00:00:00: 27.8°C, scattered clouds
